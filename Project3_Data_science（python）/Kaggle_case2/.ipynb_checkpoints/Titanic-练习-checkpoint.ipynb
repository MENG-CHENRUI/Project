# %% [markdown]
# # 泰坦尼克号生还预测问题
#
# 来源：https://www.kaggle.com/c/titanic/data
#
# 基本步骤：
# 1. Data Viewing 剖析数据
# 2. Data Preprocessing 数据预处理
# 3. Modeling 建模
# 4. Hyper-parameter Tuning 调参
# 5. Ensemble Model 集成模型

# %% [markdown]
# ## 1. Data Viewing 剖析数据
# 以可视化/统计各种方式检查拿到的数据
#
# | Variable | Definition                                 | Key                                            |
# |----------|--------------------------------------------|------------------------------------------------|
# | survival | Survival                                   | 0 = No, 1 = Yes                                |
# | pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | sibsp    | # of siblings / spouses aboard the Titanic |                                                |
# | parch    | # of parents / children aboard the Titanic |                                                |
# | ticket   | Ticket number                              |                                                |
# | fare     | Passenger fare                             |                                                |
# | cabin    | Cabin number                               |                                                |
# | embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
pd.options.display.max_columns = 50

# %%
train_df = pd.read_csv("data/train.csv", index_col="PassengerId")
train_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train_df.shape
# Out:
# (891, 11)

# %%
test_df = pd.read_csv("data/test.csv", index_col="PassengerId")
test_df.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
test_df.shape
# Out:
# (418, 10)

# %%
# 检查数据类型，有不少数字型数据和类别型数据
train_df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# from pandas_profiling import ProfileReport

# # 生成pandas profiling
# profile = ProfileReport(
#     train_df, title="Pandas Profiling Report", html={"style": {"full_width": True}}
# )

# # 保存到HTML
# profile.to_file(output_file="titanic_train.html")

# %%
# Ticket class, 1 = 1st, 2 = 2nd, 3 = 3rd
sns.countplot(x="Pclass", data=train_df, hue="Survived")

# %%
sns.countplot(x="Sex", data=train_df, hue="Survived")

# %%
# Age, 177 missing value
print(train_df.Age.isnull().sum())
train_df[train_df.Age.isnull()].head()
# Out:
# 177
#              Survived  Pclass                           Name     Sex  Age  \
# PassengerId
# 6                   0       3               Moran, Mr. James    male  NaN
# 18                  1       2   Williams, Mr. Charles Eugene    male  NaN
# 20                  1       3        Masselmani, Mrs. Fatima  female  NaN
# 27                  0       3        Emir, Mr. Farred Chehab    male  NaN
# 29                  1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0  330877   8.4583   NaN        Q
# 18               0      0  244373  13.0000   NaN        S
# 20               0      0    2649   7.2250   NaN        C
# 27               0      0    2631   7.2250   NaN        C
# 29               0      0  330959   7.8792   NaN        Q

# %%
# 对于Age不是null的部分画出具体分布图
sns.pairplot(train_df[np.logical_not(train_df.Age.isnull())], hue="Survived", vars=['Age'])

# %%
# 女性的Age 和 有没有获救的 分布图
sns.pairplot(train_df[np.logical_and(np.logical_not(train_df.Age.isnull()),train_df.Sex == "female")], hue="Survived", vars=['Age'])

# %%
# 男性的Age 和 有没有获救的 分布图
sns.pairplot(train_df[np.logical_and(np.logical_not(train_df.Age.isnull()),train_df.Sex == "male")], hue="Survived", vars=['Age'])

# %%
# SibSp 兄弟姐妹+配偶数量
sns.countplot(x="SibSp", data=train_df, hue="Survived")

# %%
# Parch 父母+孩子数量
sns.countplot(x="Parch", data=train_df, hue="Survived")

# %%
# Ticket number
# 有些人的票号是一样的

train_df.Ticket
# Out:
# PassengerId
# 1             A/5 21171
# 2              PC 17599
# 3      STON/O2. 3101282
# 4                113803
# 5                373450
#              ...
# 887              211536
# 888              112053
# 889          W./C. 6607
# 890              111369
# 891              370376
# Name: Ticket, Length: 891, dtype: object

# %%
# 票号除了全是数字之外还有一些前缀
# 查看票号的有几个部分

parts_count = []
for ticket in train_df.Ticket:
    parts_count.append(len(ticket.split()))
    
train_df['ticket_parts_count'] = parts_count
train_df.ticket_parts_count.value_counts()
# Out:
# 1    665
# 2    213
# 3     13
# Name: ticket_parts_count, dtype: int64

# %%
# 只有一个部分的票号，检查是不是全部只有数字
for ticket in train_df[train_df.ticket_parts_count == 1].Ticket:
    if not ticket.isnumeric():
        print(ticket)
# Out:
# LINE
# LINE
# LINE
# LINE

# %%
# 有2个部分的票号，检查前缀的样子
train_df[train_df.ticket_parts_count == 2].Ticket
# Out:
# PassengerId
# 1             A/5 21171
# 2              PC 17599
# 3      STON/O2. 3101282
# 11              PP 9549
# 13            A/5. 2151
#              ...
# 868            PC 17590
# 875           P/PP 3381
# 884    C.A./SOTON 34068
# 885     SOTON/OQ 392076
# 889          W./C. 6607
# Name: Ticket, Length: 213, dtype: object

# %%
# 检查前缀的样子
prefix = set()
for ticket in train_df[train_df.ticket_parts_count == 2].Ticket:
    prefix.add(ticket.split()[0])
prefix
# Out:
# {'A./5.',
#  'A.5.',
#  'A/4',
#  'A/4.',
#  'A/5',
#  'A/5.',
#  'A/S',
#  'A4.',
#  'C',
#  'C.A.',
#  'C.A./SOTON',
#  'CA',
#  'CA.',
#  'F.C.',
#  'F.C.C.',
#  'Fa',
#  'P/PP',
#  'PC',
#  'PP',
#  'S.C./A.4.',
#  'S.C./PARIS',
#  'S.O./P.P.',
#  'S.O.C.',
#  'S.O.P.',
#  'S.P.',
#  'S.W./PP',
#  'SC',
#  'SC/AH',
#  'SC/PARIS',
#  'SC/Paris',
#  'SCO/W',
#  'SO/C',
#  'SOTON/O.Q.',
#  'SOTON/O2',
#  'SOTON/OQ',
#  'STON/O2.',
#  'SW/PP',
#  'W./C.',
#  'W.E.P.',
#  'W/C',
#  'WE/P'}

# %%
# 有3个部分的票号
train_df[train_df.ticket_parts_count == 3]
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 116                 0       3                         Pekoniemi, Mr. Edvard
# 174                 0       3                     Sivola, Mr. Antti Wilhelm
# 244                 0       3                 Maenpaa, Mr. Matti Alexanteri
# 383                 0       3                            Tikkanen, Mr. Juho
# 401                 1       3                            Niskanen, Mr. Juha
# 415                 1       3                     Sundman, Mr. Johan Julian
# 434                 0       3                    Kallio, Mr. Nikolai Erland
# 474                 1       2  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)
# 580                 1       3                           Jussila, Mr. Eiriik
# 591                 0       3                          Rintamaki, Mr. Matti
# 637                 0       3                    Leinonen, Mr. Antti Gustaf
# 665                 1       3                   Lindqvist, Mr. Eino William
# 745                 1       3                            Stranden, Mr. Juho
#
#                 Sex   Age  SibSp  Parch             Ticket     Fare Cabin  \
# PassengerId
# 116            male  21.0      0      0  STON/O 2. 3101294   7.9250   NaN
# 174            male  21.0      0      0  STON/O 2. 3101280   7.9250   NaN
# 244            male  22.0      0      0  STON/O 2. 3101275   7.1250   NaN
# 383            male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN
# 401            male  39.0      0      0  STON/O 2. 3101289   7.9250   NaN
# 415            male  44.0      0      0  STON/O 2. 3101269   7.9250   NaN
# 434            male  17.0      0      0  STON/O 2. 3101274   7.1250   NaN
# 474          female  23.0      0      0    SC/AH Basle 541  13.7917     D
# 580            male  32.0      0      0  STON/O 2. 3101286   7.9250   NaN
# 591            male  35.0      0      0  STON/O 2. 3101273   7.1250   NaN
# 637            male  32.0      0      0  STON/O 2. 3101292   7.9250   NaN
# 665            male  20.0      1      0  STON/O 2. 3101285   7.9250   NaN
# 745            male  31.0      0      0  STON/O 2. 3101288   7.9250   NaN
#
#             Embarked  ticket_parts_count
# PassengerId
# 116                S                   3
# 174                S                   3
# 244                S                   3
# 383                S                   3
# 401                S                   3
# 415                S                   3
# 434                S                   3
# 474                C                   3
# 580                S                   3
# 591                S                   3
# 637                S                   3
# 665                S                   3
# 745                S                   3

# %%
# 票号最后一部分
last_part = []
for ticket in train_df.Ticket:
    last_part.append(ticket.split()[-1])
    
train_df['ticket_last_part'] = last_part
# 把"LINE"用-1代替
train_df.ticket_last_part.replace("LINE", "-1", inplace=True)
train_df.ticket_last_part.head()
# Out:
# PassengerId
# 1      21171
# 2      17599
# 3    3101282
# 4     113803
# 5     373450
# Name: ticket_last_part, dtype: object

# %%
# 把ticket_last_part有几位数的分布
train_df['ticket_last_part_len'] = train_df.ticket_last_part.str.len()
train_df.ticket_last_part_len.value_counts()
# Out:
# 6    423
# 5    246
# 4    165
# 7     44
# 3      7
# 2      4
# 1      2
# Name: ticket_last_part_len, dtype: int64

# %%
# 把ticket_last_part从string转化成数字，方便检查分布
train_df.ticket_last_part = pd.to_numeric(train_df.ticket_last_part)
sns.boxplot(x="Survived", y="ticket_last_part", data=train_df)

# %%
train_df[train_df.ticket_last_part_len == 6].ticket_last_part.hist()

# %%
# 先检查6位数ticket的分布
sns.pairplot(train_df[train_df.ticket_last_part_len == 6], hue="Survived", vars=['ticket_last_part'])

# %%
# 检查5位数ticket的分布
sns.pairplot(train_df[train_df.ticket_last_part_len == 5], hue="Survived", vars=['ticket_last_part'])

# %%
# 检查4位数ticket的分布
sns.pairplot(train_df[train_df.ticket_last_part_len == 4], hue="Survived", vars=['ticket_last_part'])

# %%
# 检查3位数ticket的分布
sns.pairplot(train_df[train_df.ticket_last_part_len == 3], hue="Survived", vars=['ticket_last_part'])

# %%
# 检查2位数ticket的分布
# 只有为LINE的4个人
train_df[train_df.ticket_last_part_len == 2]
# Out:
#              Survived  Pclass                             Name   Sex   Age  \
# PassengerId
# 180                 0       3              Leonard, Mr. Lionel  male  36.0
# 272                 1       3     Tornquist, Mr. William Henry  male  25.0
# 303                 0       3  Johnson, Mr. William Cahoone Jr  male  19.0
# 598                 0       3              Johnson, Mr. Alfred  male  49.0
#
#              SibSp  Parch Ticket  Fare Cabin Embarked  ticket_parts_count  \
# PassengerId
# 180              0      0   LINE   0.0   NaN        S                   1
# 272              0      0   LINE   0.0   NaN        S                   1
# 303              0      0   LINE   0.0   NaN        S                   1
# 598              0      0   LINE   0.0   NaN        S                   1
#
#              ticket_last_part  ticket_last_part_len
# PassengerId
# 180                        -1                     2
# 272                        -1                     2
# 303                        -1                     2
# 598                        -1                     2

# %%
# 检查1位数ticket的分布
train_df[train_df.ticket_last_part_len == 1]
# Out:
#              Survived  Pclass                      Name     Sex   Age  SibSp  \
# PassengerId
# 773                 0       2         Mack, Mrs. (Mary)  female  57.0      0
# 842                 0       2  Mudd, Mr. Thomas Charles    male  16.0      0
#
#              Parch       Ticket  Fare Cabin Embarked  ticket_parts_count  \
# PassengerId
# 773              0  S.O./P.P. 3  10.5   E77        S                   2
# 842              0  S.O./P.P. 3  10.5   NaN        S                   2
#
#              ticket_last_part  ticket_last_part_len
# PassengerId
# 773                         3                     1
# 842                         3                     1

# %%
# 有15个Passenger Fare 为0，是水手的意思吗？
train_df[train_df.Fare == 0]
# Out:
#              Survived  Pclass                              Name   Sex   Age  \
# PassengerId
# 180                 0       3               Leonard, Mr. Lionel  male  36.0
# 264                 0       1             Harrison, Mr. William  male  40.0
# 272                 1       3      Tornquist, Mr. William Henry  male  25.0
# 278                 0       2       Parkes, Mr. Francis "Frank"  male   NaN
# 303                 0       3   Johnson, Mr. William Cahoone Jr  male  19.0
# 414                 0       2    Cunningham, Mr. Alfred Fleming  male   NaN
# 467                 0       2             Campbell, Mr. William  male   NaN
# 482                 0       2  Frost, Mr. Anthony Wood "Archie"  male   NaN
# 598                 0       3               Johnson, Mr. Alfred  male  49.0
# 634                 0       1     Parr, Mr. William Henry Marsh  male   NaN
# 675                 0       2        Watson, Mr. Ennis Hastings  male   NaN
# 733                 0       2              Knight, Mr. Robert J  male   NaN
# 807                 0       1            Andrews, Mr. Thomas Jr  male  39.0
# 816                 0       1                  Fry, Mr. Richard  male   NaN
# 823                 0       1   Reuchlin, Jonkheer. John George  male  38.0
#
#              SibSp  Parch  Ticket  Fare Cabin Embarked  ticket_parts_count  \
# PassengerId
# 180              0      0    LINE   0.0   NaN        S                   1
# 264              0      0  112059   0.0   B94        S                   1
# 272              0      0    LINE   0.0   NaN        S                   1
# 278              0      0  239853   0.0   NaN        S                   1
# 303              0      0    LINE   0.0   NaN        S                   1
# 414              0      0  239853   0.0   NaN        S                   1
# 467              0      0  239853   0.0   NaN        S                   1
# 482              0      0  239854   0.0   NaN        S                   1
# 598              0      0    LINE   0.0   NaN        S                   1
# 634              0      0  112052   0.0   NaN        S                   1
# 675              0      0  239856   0.0   NaN        S                   1
# 733              0      0  239855   0.0   NaN        S                   1
# 807              0      0  112050   0.0   A36        S                   1
# 816              0      0  112058   0.0  B102        S                   1
# 823              0      0   19972   0.0   NaN        S                   1
#
#              ticket_last_part  ticket_last_part_len
# PassengerId
# 180                        -1                     2
# 264                    112059                     6
# 272                        -1                     2
# 278                    239853                     6
# 303                        -1                     2
# 414                    239853                     6
# 467                    239853                     6
# 482                    239854                     6
# 598                        -1                     2
# 634                    112052                     6
# 675                    239856                     6
# 733                    239855                     6
# 807                    112050                     6
# 816                    112058                     6
# 823                     19972                     5

# %%
# 有687个缺损值 占 77.1%
train_df.Cabin
# Out:
# PassengerId
# 1       NaN
# 2       C85
# 3       NaN
# 4      C123
# 5       NaN
#        ...
# 887     NaN
# 888     B42
# 889     NaN
# 890    C148
# 891     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# Cabin 房间号, 有些人的房间号是一样的

parts_count = []
for cabin in train_df.Cabin:
    if type(cabin) != float:
        parts_count.append(len(cabin.split()))
    else:
        parts_count.append(0)
    
train_df['cabin_count'] = parts_count
train_df.cabin_count.value_counts()
# Out:
# 0    687
# 1    180
# 2     16
# 3      6
# 4      2
# Name: cabin_count, dtype: int64

# %%
train_df[train_df.cabin_count==2]
# Out:
#              Survived  Pclass  \
# PassengerId
# 76                  0       3
# 98                  1       1
# 119                 0       1
# 129                 1       3
# 298                 0       1
# 300                 1       1
# 306                 1       1
# 391                 1       1
# 436                 1       1
# 499                 0       1
# 700                 0       3
# 701                 1       1
# 716                 0       3
# 764                 1       1
# 790                 0       1
# 803                 1       1
#
#                                                           Name     Sex    Age  \
# PassengerId
# 76                                     Moen, Mr. Sigurd Hansen    male  25.00
# 98                             Greenfield, Mr. William Bertram    male  23.00
# 119                                   Baxter, Mr. Quigg Edmond    male  24.00
# 129                                          Peter, Miss. Anna  female    NaN
# 298                               Allison, Miss. Helen Loraine  female   2.00
# 300            Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00
# 306                             Allison, Master. Hudson Trevor    male   0.92
# 391                                 Carter, Mr. William Ernest    male  36.00
# 436                                  Carter, Miss. Lucile Polk  female  14.00
# 499            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 700                   Humblen, Mr. Adolf Mathias Nicolai Olsen    male  42.00
# 701          Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00
# 716                 Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.00
# 764                  Carter, Mrs. William Ernest (Lucile Polk)  female  36.00
# 790                                   Guggenheim, Mr. Benjamin    male  46.00
# 803                        Carter, Master. William Thornton II    male  11.00
#
#              SibSp  Parch    Ticket      Fare    Cabin Embarked  \
# PassengerId
# 76               0      0    348123    7.6500    F G73        S
# 98               0      1  PC 17759   63.3583  D10 D12        C
# 119              0      1  PC 17558  247.5208  B58 B60        C
# 129              1      1      2668   22.3583    F E69        C
# 298              1      2    113781  151.5500  C22 C26        S
# 300              0      1  PC 17558  247.5208  B58 B60        C
# 306              1      2    113781  151.5500  C22 C26        S
# 391              1      2    113760  120.0000  B96 B98        S
# 436              1      2    113760  120.0000  B96 B98        S
# 499              1      2    113781  151.5500  C22 C26        S
# 700              0      0    348121    7.6500    F G63        S
# 701              1      0  PC 17757  227.5250  C62 C64        C
# 716              0      0    348124    7.6500    F G73        S
# 764              1      2    113760  120.0000  B96 B98        S
# 790              0      0  PC 17593   79.2000  B82 B84        C
# 803              1      2    113760  120.0000  B96 B98        S
#
#              ticket_parts_count  ticket_last_part  ticket_last_part_len  \
# PassengerId
# 76                            1            348123                     6
# 98                            2             17759                     5
# 119                           2             17558                     5
# 129                           1              2668                     4
# 298                           1            113781                     6
# 300                           2             17558                     5
# 306                           1            113781                     6
# 391                           1            113760                     6
# 436                           1            113760                     6
# 499                           1            113781                     6
# 700                           1            348121                     6
# 701                           2             17757                     5
# 716                           1            348124                     6
# 764                           1            113760                     6
# 790                           2             17593                     5
# 803                           1            113760                     6
#
#              cabin_count
# PassengerId
# 76                     2
# 98                     2
# 119                    2
# 129                    2
# 298                    2
# 300                    2
# 306                    2
# 391                    2
# 436                    2
# 499                    2
# 700                    2
# 701                    2
# 716                    2
# 764                    2
# 790                    2
# 803                    2

# %%
# 检查cabin的各个部分
cabin_parts = []
for cabin in train_df.Cabin:
    if type(cabin) != float:
        cabin_parts += cabin.split()
    else:
        continue
cabin_parts
# Out:
# ['C85',
#  'C123',
#  'E46',
#  'G6',
#  'C103',
#  'D56',
#  'A6',
#  'C23',
#  'C25',
#  'C27',
#  'B78',
#  'D33',
#  'B30',
#  'C52',
#  'B28',
#  'C83',
#  'F33',
#  'F',
#  'G73',
#  'C23',
#  'C25',
#  'C27',
#  'E31',
#  'A5',
#  'D10',
#  'D12',
#  'D26',
#  'C110',
#  'B58',
#  'B60',
#  'E101',
#  'D26',
#  'F',
#  'E69',
#  'D47',
#  'C123',
#  'B86',
#  'F2',
#  'C2',
#  'E33',
#  'B19',
#  'A7',
#  'C49',
#  'F4',
#  'A32',
#  'F2',
#  'B4',
#  'B80',
#  'G6',
#  'A31',
#  'D36',
#  'D15',
#  'C93',
#  'C83',
#  'C78',
#  'D35',
#  'G6',
#  'C87',
#  'B77',
#  'E67',
#  'B94',
#  'C125',
#  'C99',
#  'C118',
#  'D7',
#  'A19',
#  'B49',
#  'D',
#  'C22',
#  'C26',
#  'C106',
#  'B58',
#  'B60',
#  'E101',
#  'C22',
#  'C26',
#  'C65',
#  'E36',
#  'C54',
#  'B57',
#  'B59',
#  'B63',
#  'B66',
#  'C7',
#  'E34',
#  'C32',
#  'D',
#  'B18',
#  'C124',
#  'C91',
#  'C2',
#  'E40',
#  'T',
#  'F2',
#  'C23',
#  'C25',
#  'C27',
#  'F33',
#  'C128',
#  'E33',
#  'D37',
#  'B35',
#  'E50',
#  'C82',
#  'B96',
#  'B98',
#  'D36',
#  'G6',
#  'C78',
#  'E10',
#  'C52',
#  'E44',
#  'B96',
#  'B98',
#  'C23',
#  'C25',
#  'C27',
#  'A34',
#  'C104',
#  'C111',
#  'C92',
#  'E38',
#  'D21',
#  'E12',
#  'E63',
#  'D',
#  'A14',
#  'B49',
#  'C93',
#  'B37',
#  'C30',
#  'D20',
#  'C22',
#  'C26',
#  'B79',
#  'C65',
#  'E25',
#  'D46',
#  'F33',
#  'B73',
#  'B18',
#  'C95',
#  'B38',
#  'B39',
#  'B22',
#  'C86',
#  'C70',
#  'A16',
#  'E67',
#  'C101',
#  'E25',
#  'E44',
#  'C68',
#  'A10',
#  'E68',
#  'B41',
#  'D20',
#  'A20',
#  'C125',
#  'F4',
#  'D19',
#  'D50',
#  'D9',
#  'A23',
#  'B50',
#  'B35',
#  'D33',
#  'A26',
#  'D48',
#  'E58',
#  'C126',
#  'B71',
#  'B51',
#  'B53',
#  'B55',
#  'D49',
#  'B5',
#  'B20',
#  'C68',
#  'F',
#  'G63',
#  'C62',
#  'C64',
#  'E24',
#  'E24',
#  'C90',
#  'C124',
#  'C126',
#  'F',
#  'G73',
#  'C45',
#  'E101',
#  'E8',
#  'B5',
#  'B101',
#  'D45',
#  'C46',
#  'B57',
#  'B59',
#  'B63',
#  'B66',
#  'B22',
#  'D30',
#  'E121',
#  'B77',
#  'B96',
#  'B98',
#  'D11',
#  'E77',
#  'F38',
#  'B3',
#  'B20',
#  'D6',
#  'B82',
#  'B84',
#  'D17',
#  'B96',
#  'B98',
#  'A36',
#  'E8',
#  'B102',
#  'B69',
#  'E121',
#  'B28',
#  'E49',
#  'C47',
#  'C92',
#  'D28',
#  'E17',
#  'D17',
#  'A24',
#  'D35',
#  'B51',
#  'B53',
#  'B55',
#  'C50',
#  'B42',
#  'C148']

# %%
first_char = [x[0] for x in cabin_parts]
pd.Series(first_char).value_counts()
# Out:
# C    71
# B    64
# D    34
# E    33
# A    15
# F    13
# G     7
# T     1
# dtype: int64

# %%
train_df[train_df.cabin_count==2]
# Out:
#              Survived  Pclass  \
# PassengerId
# 76                  0       3
# 98                  1       1
# 119                 0       1
# 129                 1       3
# 298                 0       1
# 300                 1       1
# 306                 1       1
# 391                 1       1
# 436                 1       1
# 499                 0       1
# 700                 0       3
# 701                 1       1
# 716                 0       3
# 764                 1       1
# 790                 0       1
# 803                 1       1
#
#                                                           Name     Sex    Age  \
# PassengerId
# 76                                     Moen, Mr. Sigurd Hansen    male  25.00
# 98                             Greenfield, Mr. William Bertram    male  23.00
# 119                                   Baxter, Mr. Quigg Edmond    male  24.00
# 129                                          Peter, Miss. Anna  female    NaN
# 298                               Allison, Miss. Helen Loraine  female   2.00
# 300            Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00
# 306                             Allison, Master. Hudson Trevor    male   0.92
# 391                                 Carter, Mr. William Ernest    male  36.00
# 436                                  Carter, Miss. Lucile Polk  female  14.00
# 499            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 700                   Humblen, Mr. Adolf Mathias Nicolai Olsen    male  42.00
# 701          Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00
# 716                 Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.00
# 764                  Carter, Mrs. William Ernest (Lucile Polk)  female  36.00
# 790                                   Guggenheim, Mr. Benjamin    male  46.00
# 803                        Carter, Master. William Thornton II    male  11.00
#
#              SibSp  Parch    Ticket      Fare    Cabin Embarked  \
# PassengerId
# 76               0      0    348123    7.6500    F G73        S
# 98               0      1  PC 17759   63.3583  D10 D12        C
# 119              0      1  PC 17558  247.5208  B58 B60        C
# 129              1      1      2668   22.3583    F E69        C
# 298              1      2    113781  151.5500  C22 C26        S
# 300              0      1  PC 17558  247.5208  B58 B60        C
# 306              1      2    113781  151.5500  C22 C26        S
# 391              1      2    113760  120.0000  B96 B98        S
# 436              1      2    113760  120.0000  B96 B98        S
# 499              1      2    113781  151.5500  C22 C26        S
# 700              0      0    348121    7.6500    F G63        S
# 701              1      0  PC 17757  227.5250  C62 C64        C
# 716              0      0    348124    7.6500    F G73        S
# 764              1      2    113760  120.0000  B96 B98        S
# 790              0      0  PC 17593   79.2000  B82 B84        C
# 803              1      2    113760  120.0000  B96 B98        S
#
#              ticket_parts_count  ticket_last_part  ticket_last_part_len  \
# PassengerId
# 76                            1            348123                     6
# 98                            2             17759                     5
# 119                           2             17558                     5
# 129                           1              2668                     4
# 298                           1            113781                     6
# 300                           2             17558                     5
# 306                           1            113781                     6
# 391                           1            113760                     6
# 436                           1            113760                     6
# 499                           1            113781                     6
# 700                           1            348121                     6
# 701                           2             17757                     5
# 716                           1            348124                     6
# 764                           1            113760                     6
# 790                           2             17593                     5
# 803                           1            113760                     6
#
#              cabin_count
# PassengerId
# 76                     2
# 98                     2
# 119                    2
# 129                    2
# 298                    2
# 300                    2
# 306                    2
# 391                    2
# 436                    2
# 499                    2
# 700                    2
# 701                    2
# 716                    2
# 764                    2
# 790                    2
# 803                    2

# %%
# Embarked 入境口，有2个缺损值
sns.countplot(x="Embarked", data=train_df[np.logical_not(train_df.Embarked.isnull())], hue="Survived")

# %%
train_df[train_df.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  \
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN
#
#              ticket_parts_count  ticket_last_part  ticket_last_part_len  \
# PassengerId
# 62                            1            113572                     6
# 830                           1            113572                     6
#
#              cabin_count
# PassengerId
# 62                     1
# 830                    1

# %%
# 查看 test里面的Embarked有没有缺损值
test_df[test_df.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ## Data Preprocessing 数据预处理
#
# 目的：清理数据，对于数据做一些适当的处理使之可以让模型训练
#
# 时间：25-30分钟
#
# 1. 处理缺损值/Outlier
# 2. 若有必要转换类别型数据
# 3. 特征工程，生成有意义的特征
# 4. 分成不同数据集，training evaluation testing (此次测试数据集使用网站上准备的test.csv)
# 5. 缩放数据：归一化，标准化等等

# %% [markdown]
# ### 处理票号？那几个票号为LINE的人怎么办？
# - 特征same_ticket_ppl：跟自己一样票号的人数
# - 特征ticket_part_count: 票号有几个部分
# - 特征ticket_last_part: 票号最后部分的数值
# - 特征ticket_last_part_len: 票号最后部分的长度
# ### 处理Cabin？
# - 特征same_cabin_ppl：跟自己一样房间号的人数
# - 特征cabin_X_count: 有X级房间的数量（X为ABCDEFGT）
# - 特征cabin_exists: 有没有cabin的记录
# - 特征cabin_count: 总共拥有的房间数量
# ### embarked只在train数据集中出现
# - 直接删掉
# ### Name 删掉。。。
# - 不知道该怎么处理
# ### Sex 和 Embarked用encoding转换
# ### age的缺损值
# 在数据归一化之后，用-1或者平均值代替

# %%
# 因为data viewing的时候对train_df做了一些改变，现在重新载入准备预处理
train_df = pd.read_csv("data/train.csv", index_col="PassengerId")
print(train_df.shape)
test_df = pd.read_csv("data/test.csv", index_col="PassengerId")
print(test_df.shape)
# Out:
# (891, 11)
# (418, 10)

# %%
# 处理票号？
# 处理Cabin？
# cabin, embarked & age的缺损值怎么办？
obj_col = [x for x in train_df.columns if train_df[x].dtype == object]
num_col = [x for x in train_df.columns if x not in obj_col]
print(obj_col)
print(num_col)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
train_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
#删掉Name和Embarked
train_df.drop(columns=["Name","Embarked"])
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# PassengerId
# 1                   0       3    male  22.0      1      0         A/5 21171
# 2                   1       1  female  38.0      1      0          PC 17599
# 3                   1       3  female  26.0      0      0  STON/O2. 3101282
# 4                   1       1  female  35.0      1      0            113803
# 5                   0       3    male  35.0      0      0            373450
# ...               ...     ...     ...   ...    ...    ...               ...
# 887                 0       2    male  27.0      0      0            211536
# 888                 1       1  female  19.0      0      0            112053
# 889                 0       3  female   NaN      1      2        W./C. 6607
# 890                 1       1    male  26.0      0      0            111369
# 891                 0       3    male  32.0      0      0            370376
#
#                 Fare Cabin
# PassengerId
# 1             7.2500   NaN
# 2            71.2833   C85
# 3             7.9250   NaN
# 4            53.1000  C123
# 5             8.0500   NaN
# ...              ...   ...
# 887          13.0000   NaN
# 888          30.0000   B42
# 889          23.4500   NaN
# 890          30.0000  C148
# 891           7.7500   NaN
#
# [891 rows x 9 columns]

# %%
#处理缺损值Age,Ticket,Cabin,Embarked

#Age在数据归一化之后，用-1或者平均值代替
#train_df.fillna({'Age':-1})

#Ticket特征添加
### 处理票号？那几个票号为LINE的人怎么办？
# - 特征same_ticket_ppl：跟自己一样票号的人数
# - 特征ticket_part_count: 票号有几个部分
# - 特征ticket_last_part: 票号最后部分的数值
# - 特征ticket_last_part_len: 票号最后部分的长度
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  -1.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
categorial_colms = 

onehotencoder = OneHotEncoder()
# 训练OneHotEncoder
onehotencoder.fit(train_df[categorial_colms])
# 得到转换的encoding
train_cat = onehotencoder.transform(train_df[categorial_colms])
test_cat = onehotencoder.transform(test_df[categorial_colms])

# %% [markdown]
# ## Modeling 建模 + 调参
#
# 时间：25分钟
#
# - Titanic的模型评估方法为Accuracy
# - 建模（必须）+ 使用Grid Search调整超参数：
#     - SVM
#     - 逻辑回归
#     - KNN
#     - Decision Tree
# - 建模（选做）：
#     - Random Forest

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
feature_cols = test_df.columns.tolist()
print(feature_cols)

# %%
# 创建模型和grid search的参数
svc_clf = SVC(gamma="auto")
svc_clf = GridSearchCV(
    svc_clf,
    {
        "kernel": ["linear", "rbf", "sigmoid"],
        "C": [0.1, 1, 3],
        "class_weight": ["balanced", None],
        "gamma": [0.1, "auto", 0.5],
    },
    cv=3,
    scoring="accuracy",
)

# 开始grid search
svc_clf.fit(train_df[feature_cols], train_df.Survived)
print(svc_clf.best_score_)
print(svc_clf.best_params_)

# %%
# LogisticRegression
lr_clf = LogisticRegression(solver="lbfgs")
lr_clf = GridSearchCV(
    lr_clf, {"class_weight": ["balanced", None]}, cv=5, scoring="accuracy"
)

# 开始grid search
lr_clf.fit(train_df[feature_cols], train_df.Survived)
print(lr_clf.best_score_)
print(lr_clf.best_params_)

# %%
# KNeighborsClassifier
knn_clf = KNeighborsClassifier()
knn_clf = GridSearchCV(knn_clf, {"n_neighbors": [2, 3, 4]}, cv=3, scoring="accuracy")

# 开始grid search
knn_clf.fit(train_df[feature_cols], train_df.Survived)
print(knn_clf.best_score_)
print(knn_clf.best_params_)

# %%
# DecisionTreeClassifier
dt_clf = DecisionTreeClassifier()
dt_clf = GridSearchCV(
    dt_clf,
    {"criterion": ["gini", "entropy"], "max_depth": [6, 8, 10, 12, None]},
    cv=5,
    scoring="accuracy",
)

# 开始grid search
dt_clf.fit(train_df[feature_cols], train_df.Survived)
print(dt_clf.best_score_)
print(dt_clf.best_params_)

# %%
# RandomForestClassifier
rf_clf = RandomForestClassifier(criterion="entropy", max_depth=6)
rf_clf = GridSearchCV(
    rf_clf,
    {"n_estimators": [60, 80, 100], "max_depth": [4, 5, 6, None]},
    cv=5,
    scoring="accuracy",
)

# 开始grid search
rf_clf.fit(train_df[feature_cols], train_df.Survived)
rf_clf.best_score_
print(rf_clf.best_score_)
print(rf_clf.best_params_)

# %% [markdown]
# ## 分析模型
#
# 目的：评估生成的模型，查看是否有过拟合的显现，是否有必要调整数据集，增/减特征等等
#
# 时间：15分钟
#
# - 整理出每个模型的评估结果（confusion matrix，精确率和召回率等等）
# - 对于可以算出特征重要度(clf.feature_importances_)的模型（SVM，Linear Regression等等）查看什么特征对于预测更重要，考虑是否增/减特征

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve

# %%
# 我们此次的评估标准为Accuracy

# 因为grid search的时候已经定义了Accuracy为score，可以直接用best score调用
score_df = pd.DataFrame()
score_df["val"] = [
    svc_clf.best_score_,
    lr_clf.best_score_,
    dt_clf.best_score_,
    knn_clf.best_score_,
    rf_clf.best_score_,
]
score_df["model"] = ["SVC", "LR", "DT", "KNN", "RF"]
score_df.plot(kind='bar', x="model", y="val")

# %%
score_df

# %%
# random forest 的线下面积最高，查看模型的特征重要度
importance_df = pd.DataFrame()
importance_df['val'] = rf_clf.best_estimator_.feature_importances_
importance_df['col'] = test_df.columns.values
importance_df.plot(kind='bar', x="col", y="val", figsize=(20,5))

# %% [markdown]
# ## 预测结果
#
# 时间：15分钟
#
# - 使用同样的数据预处理方法整理test.csv的数据
# - 用训练好的模型预测测试数据集
# - 上传结果到Kaggle网站上看自己的分数

# %% [markdown]
# ## Ensemble Model 集成模型
#
# 时间：20分钟
#
# - 选2个或以上表现较好，算法差别较远的模型进行集成
# - 预测测试数据集的集成结果
# - 上传集成结果到Kaggle网站上看自己的分数
